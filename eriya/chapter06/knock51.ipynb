# %%
from gensim.models import KeyedVectors

# モデルを読み込み（パスは必要に応じて変更）
model = KeyedVectors.load_word2vec_format("GoogleNews-vectors-negative300.bin.gz", binary=True)

# コサイン類似度を計算（注意: 単語は "United_States" のように記述）
similarity = model.similarity("United_States", "U.S.")

print(f'Cosine similarity between "United States" and "U.S.": {similarity:.4f}')
# Out:
# Cosine similarity between "United States" and "U.S.": 0.7311
