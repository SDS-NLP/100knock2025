# %%
from gensim.models import KeyedVectors

# モデルの読み込み（パスは必要に応じて変更）
model = KeyedVectors.load_word2vec_format("GoogleNews-vectors-negative300.bin.gz", binary=True)

# “United_States” に類似する単語トップ10を取得
similar_words = model.most_similar("United_States", topn=10)

# 結果を出力
print("🔍 'United_States' に類似する単語トップ10:")
for word, similarity in similar_words:
    print(f"{word:20} : {similarity:.4f}")
# Out:
# 🔍 'United_States' に類似する単語トップ10:
# Unites_States        : 0.7877
# Untied_States        : 0.7541
# United_Sates         : 0.7401
# U.S.                 : 0.7311
# theUnited_States     : 0.6404
# America              : 0.6178
# UnitedStates         : 0.6167
# Europe               : 0.6133
# countries            : 0.6045
# Canada               : 0.6019
