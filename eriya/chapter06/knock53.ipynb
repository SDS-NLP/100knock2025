# %%
from gensim.models import KeyedVectors

# モデルの読み込み
model = KeyedVectors.load_word2vec_format("GoogleNews-vectors-negative300.bin.gz", binary=True)

# アナロジーベクトルの計算: Spain - Madrid + Athens
results = model.most_similar(positive=["Athens", "Spain"], negative=["Madrid"], topn=10)

# 結果の出力
print("🔍 Spain - Madrid + Athens に類似する単語トップ10:")
for word, similarity in results:
    print(f"{word:20} : {similarity:.4f}")
# Out:
# 🔍 Spain - Madrid + Athens に類似する単語トップ10:
# Greece               : 0.6898
# Aristeidis_Grigoriadis : 0.5607
# Ioannis_Drymonakos   : 0.5553
# Greeks               : 0.5451
# Ioannis_Christou     : 0.5401
# Hrysopiyi_Devetzi    : 0.5248
# Heraklio             : 0.5208
# Athens_Greece        : 0.5169
# Lithuania            : 0.5167
# Iraklion             : 0.5147
