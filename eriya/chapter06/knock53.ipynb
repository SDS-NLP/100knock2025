# %%
from gensim.models import KeyedVectors

# モデルの読み込み
model = KeyedVectors.load_word2vec_format("GoogleNews-vectors-negative300.bin.gz", binary=True)

# アナロジーベクトルの計算: Spain - Madrid + Athens
results = model.most_similar(positive=["Queen", "Man"], negative=["Woman"], topn=10)

# 結果の出力
print("🔍 Spain - Madrid + Athens に類似する単語トップ10:")
for word, similarity in results:
    print(f"{word:20} : {similarity:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from gensim.models import KeyedVectors
#       3 # モデルの読み込み
#       4 model = KeyedVectors.load_word2vec_format("GoogleNews-vectors-negative300.bin.gz", binary=True)
#
# ModuleNotFoundError: No module named 'gensim'
