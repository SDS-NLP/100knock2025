# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel
import torch

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")
model.eval()

prompt = "The movie was full of"
input_ids = tokenizer.encode(prompt, return_tensors="pt")

for temp in [0.7, 1.0, 1.5]:
    print(f"=== Temperature: {temp} ===")
    output_ids = model.generate(
        input_ids,
        max_length=20,
        do_sample=True,
        temperature=temp,
        top_k=50,
        top_p=0.95,
        num_return_sequences=3,
    )
    for i, out in enumerate(output_ids):
        print(f"{i+1}: {tokenizer.decode(out, skip_special_tokens=True)}\n")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# === Temperature: 0.7 ===
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 1: The movie was full of fun, but it was not a very good one. I can only imagine
#
# 2: The movie was full of surprises, including the new character, the famous "Ginger" who was
#
# 3: The movie was full of great moments, but also some who were not in the movie. Some were
#
# === Temperature: 1.0 ===
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 1: The movie was full of humor and it took an hour before it took off from the movie. And
#
# 2: The movie was full of fun, which will be exciting for you.
#
# Why does the studio
#
# 3: The movie was full of hilarious dialogue and character moments, as he was often asked whether to sing the
#
# === Temperature: 1.5 ===
# 1: The movie was full of the most iconic features of all to date
#
# And if we're honest
#
# 2: The movie was full of characters who were both heroes and antagonists: Jaws's dad on a bus
#
# 3: The movie was full of action-oriented shots that were aimed at capturing the characters being seen for the
