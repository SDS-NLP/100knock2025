# %%
import pickle
from collections import defaultdict


def add_feature(sentence):
    data = {"feature": defaultdict(int)}
    for token in sentence.split():
        data["feature"][token] += 1
    return data


def predict_sentiment(text):
    # モデルとベクトライザーの読み込み
    with open("../chapter07/logistic_model.pkl", "rb") as f:
        model = pickle.load(f)
    with open("../chapter07/vectorizer.pkl", "rb") as f:
        vec = pickle.load(f)

    # 特徴ベクトルの構築
    data = add_feature(text)

    # 特徴ベクトルの変換
    X = vec.transform([data["feature"]])

    # 予測
    predicted_label = model.predict(X)[0]
    predicted_prob = model.predict_proba(X)[0]

    # 結果の表示
    sentiment = "ポジティブ" if predicted_label == 1 else "ネガティブ"
    print(f"テキスト: {text}")
    print(f"予測された感情: {sentiment}")
    print(
        f"予測確率: ネガティブ={predicted_prob[0]:.4f}, ポジティブ={predicted_prob[1]:.4f}"
    )


# テスト用のテキスト
test_text = "the worst movie I 've ever seen"
predict_sentiment(test_text)

print("\n対話的にテキストを入力して予測します。終了するには 'q' を入力してください。")
print("--------------------------------")

while True:
    text = input("\nテキストを入力してください: ")
    if text.lower() == "q":
        break
    predict_sentiment(text)
# Out:
# テキスト: the worst movie I 've ever seen
# 予測された感情: ネガティブ
# 予測確率: ネガティブ=0.9775, ポジティブ=0.0225
#
# 対話的にテキストを入力して予測します。終了するには 'q' を入力してください。
# テキスト: I'm happy
# 予測された感情: ポジティブ
# 予測確率: ネガティブ=0.0876, ポジティブ=0.9124
# テキスト:
# 予測された感情: ポジティブ
# 予測確率: ネガティブ=0.4154, ポジティブ=0.5846
# テキスト: I'm  feeling bad
# 予測された感情: ネガティブ
# 予測確率: ネガティブ=0.8801, ポジティブ=0.1199
# テキスト: neutral
# 予測された感情: ネガティブ
# 予測確率: ネガティブ=0.6738, ポジティブ=0.3262
# テキスト: meow
# 予測された感情: ポジティブ
# 予測確率: ネガティブ=0.2195, ポジティブ=0.7805
# テキスト: woof
# 予測された感情: ポジティブ
# 予測確率: ネガティブ=0.4154, ポジティブ=0.5846
