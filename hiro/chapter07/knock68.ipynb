# %%
import pickle

# モデルとベクトライザーの読み込み
with open("../chapter07/logistic_model.pkl", "rb") as f:
    model = pickle.load(f)
with open("../chapter07/vectorizer.pkl", "rb") as f:
    vec = pickle.load(f)

# 特徴量名の取得
feature_names = vec.get_feature_names_out()

# モデルの重みを取得
weights = model.coef_[0]

# 重みと特徴量名のペアを作成
weight_feature_pairs = list(zip(weights, feature_names))

# 重みの高い特徴量トップ20を取得
top_20_positive = sorted(weight_feature_pairs, key=lambda x: x[0], reverse=True)[:20]

# 重みの低い特徴量トップ20を取得
top_20_negative = sorted(weight_feature_pairs, key=lambda x: x[0])[:20]

# 結果の表示
print("重みの高い特徴量トップ20:")
for i, (weight, feature) in enumerate(top_20_positive, 1):
    print(f"{i}. {feature}: {weight:.4f}")

print("\n重みの低い特徴量トップ20:")
for i, (weight, feature) in enumerate(top_20_negative, 1):
    print(f"{i}. {feature}: {weight:.4f}")
# Out:
# 重みの高い特徴量トップ20:
# 1. refreshing: 3.4370
# 2. remarkable: 3.4346
# 3. powerful: 3.2249
# 4. hilarious: 3.1854
# 5. beautiful: 3.0043
# 6. wonderful: 2.9745
# 7. prose: 2.9200
# 8. terrific: 2.8789
# 9. appealing: 2.8590
# 10. enjoyable: 2.8185
# 11. treat: 2.8094
# 12. charmer: 2.7555
# 13. vividly: 2.7168
# 14. likable: 2.6941
# 15. solid: 2.6556
# 16. fascinating: 2.6213
# 17. charming: 2.6206
# 18. half-bad: 2.6118
# 19. impressive: 2.5992
# 20. intriguing: 2.5644
#
# 重みの低い特徴量トップ20:
# 1. lacking: -4.3395
# 2. lacks: -4.0830
# 3. worst: -3.9842
# 4. devoid: -3.6597
# 5. mess: -3.6284
# 6. failure: -3.5880
# 7. stupid: -3.3514
# 8. bore: -3.2614
# 9. flat: -3.2268
# 10. depressing: -3.2041
# 11. loses: -3.1776
# 12. waste: -3.1596
# 13. lack: -3.0627
# 14. squanders: -3.0370
# 15. hardly: -3.0290
# 16. none: -3.0212
# 17. poor: -2.9874
# 18. pointless: -2.9665
# 19. unfortunately: -2.9462
# 20. lousy: -2.9421
