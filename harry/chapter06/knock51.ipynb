# %%
word1 = "United_States"
word2 = "U.S."

# 単語がモデルにあるかを確認
if word1 in model and word2 in model:
    similarity = model.similarity(word1, word2)
    print(f"✅ '{word1}' と '{word2}' のコサイン類似度: {similarity:.4f}")
else:
    print(f"❌ どちらかの単語がモデルに含まれていません。")
