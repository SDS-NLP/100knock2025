# %%
# 単語のベクトル演算: Spain - Madrid + Athens
positive = ["Athens", "Spain"]
negative = ["Madrid"]

try:
    print("🧠 ベクトル演算: Spain - Madrid + Athens")
    results = model.most_similar(positive=positive, negative=negative, topn=10)
    print("🔍 類似度の高い単語トップ10:")
    for word, score in results:
        print(f"  {word:20s} 類似度: {score:.4f}")
except KeyError as e:
    print(f"❌ エラー: {e}")
