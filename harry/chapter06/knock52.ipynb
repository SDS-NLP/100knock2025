# %%
target_word = "United_States"

if target_word in model:
    print(f"🔍 '{target_word}' に類似した単語トップ10:")
    similar_words = model.most_similar(target_word, topn=10)
    for word, similarity in similar_words:
        print(f"  {word:20s} 類似度: {similarity:.4f}")
else:
    print(f"❌ '{target_word}' はモデルに存在しません。")
